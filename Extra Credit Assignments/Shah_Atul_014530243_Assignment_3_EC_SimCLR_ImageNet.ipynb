# %% [markdown]
# <a href="https://colab.research.google.com/github/atulshah16/EmergingTechnologiesCMPE297/blob/master/Extra%20Credit%20Assignments/Shah_Atul_014530243_Assignment_3_EC_SimCLR_ImageNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Name: Atul Shah
# ## Student ID: 01450243

# %% [markdown]
# ## SimCLR implementation on Imagenet Data

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
# !nvidia-smi
# Out:
# Wed Dec 16 03:40:49 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Install wandb for experiment tracking
# !pip install --upgrade https://github.com/wandb/client/archive/feature/code-save.zip
# Out:
# Collecting https://github.com/wandb/client/archive/feature/code-save.zip
#   Downloading https://github.com/wandb/client/archive/feature/code-save.zip
#      - 16.7MB 32.1MB/s
# Requirement already satisfied, skipping upgrade: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (7.1.2)
# Collecting GitPython>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/24/d1/a7f8fe3df258549b303415157328bfcc63e9b11d06a7ad7a3327f3d32606/GitPython-3.1.11-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 13.5MB/s
# Collecting gql==0.2.0
#   Downloading https://files.pythonhosted.org/packages/c4/6f/cf9a3056045518f06184e804bae89390eb706168349daa9dff8ac609962a/gql-0.2.0.tar.gz
# Requirement already satisfied, skipping upgrade: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (7.352.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (2.8.1)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (2.23.0)
# Collecting shortuuid>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/25/a6/2ecc1daa6a304e7f1b216f0896b26156b78e7c38e1211e9b798b4716c53d/shortuuid-1.0.1-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (1.15.0)
# Collecting watchdog>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/e6/76/39d123d37908a772b6a281d85fbb4384d9db7e13d19d10ad409006bd2962/watchdog-1.0.1.tar.gz (97kB)
#      |████████████████████████████████| 102kB 9.8MB/s
# Requirement already satisfied, skipping upgrade: PyYAML>=3.10 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (3.13)
# Requirement already satisfied, skipping upgrade: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb==0.8.36) (5.4.8)
# Collecting sentry-sdk>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/b1/5c/018bf9a5c24343a664deaea70e61f33f53bb1bd3caf193110f827bfd07e2/sentry_sdk-0.19.5-py2.py3-none-any.whl (128kB)
#      |████████████████████████████████| 133kB 33.7MB/s
# Collecting subprocess32>=3.5.3
#   Downloading https://files.pythonhosted.org/packages/32/c8/564be4d12629b912ea431f1a50eb8b3b9d00f1a0b1ceff17f266be190007/subprocess32-3.5.4.tar.gz (97kB)
#      |████████████████████████████████| 102kB 15.2MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting configparser>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/08/b2/ef713e0e67f6e7ec7d59aea3ee78d05b39c15930057e724cc6d362a8c3bb/configparser-5.0.1-py3-none-any.whl
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 13.0MB/s
# Collecting graphql-core<2,>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/b0/89/00ad5e07524d8c523b14d70c685e0299a8b0de6d0727e368c41b89b7ed0b/graphql-core-1.1.tar.gz (70kB)
#      |████████████████████████████████| 71kB 10.6MB/s
# Requirement already satisfied, skipping upgrade: promise<3,>=2.0 in /usr/local/lib/python3.6/dist-packages (from gql==0.2.0->wandb==0.8.36) (2.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb==0.8.36) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb==0.8.36) (2020.12.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb==0.8.36) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb==0.8.36) (2.10)
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Building wheels for collected packages: wandb, gql, watchdog, subprocess32, graphql-core
#   Building wheel for wandb (setup.py) ... done
#   Created wheel for wandb: filename=wandb-0.8.36-py2.py3-none-any.whl size=1385043 sha256=f02319e8d5c59ebacd580e2d2ce9d5b62674812950b8b7d621928bfb065c75f9
#   Stored in directory: /root/.cache/pip/wheels/6e/96/54/f4aafa18d112d4c6e313ac393b3b85513d090dd15b37357f19
#   Building wheel for gql (setup.py) ... done
#   Created wheel for gql: filename=gql-0.2.0-cp36-none-any.whl size=7630 sha256=5c3639bbcccfd9d309a2ea652e22829f1af4ad4264f4b343860fd73695041e70
#   Stored in directory: /root/.cache/pip/wheels/ce/0e/7b/58a8a5268655b3ad74feef5aa97946f0addafb3cbb6bd2da23
#   Building wheel for watchdog (setup.py) ... done
#   Created wheel for watchdog: filename=watchdog-1.0.1-cp36-none-any.whl size=72206 sha256=c77b0f57e4dc479f9994a0603be7d2f611bd6c37cfb986e38de481225ce11ea4
#   Stored in directory: /root/.cache/pip/wheels/d8/ce/d8/31a48288b5728794feda5ac479fa324cc1cde4398c29eff064
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp36-none-any.whl size=6489 sha256=68d4d2748913764b5815090cd9d5aee7a4a3a324bc9ae504144aaddd52e64217
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
#   Building wheel for graphql-core (setup.py) ... done
#   Created wheel for graphql-core: filename=graphql_core-1.1-cp36-none-any.whl size=104651 sha256=6b125537107cb340c79fa55ff0c011f9ff4a02f9eac0c8bcaa97d85950589ad9
#   Stored in directory: /root/.cache/pip/wheels/45/99/d7/c424029bb0fe910c63b68dbf2aa20d3283d023042521bcd7d5
# Successfully built wandb gql watchdog subprocess32 graphql-core
# Installing collected packages: smmap, gitdb, GitPython, graphql-core, gql, shortuuid, watchdog, sentry-sdk, subprocess32, docker-pycreds, configparser, wandb
# Successfully installed GitPython-3.1.11 configparser-5.0.1 docker-pycreds-0.4.0 gitdb-4.0.5 gql-0.2.0 graphql-core-1.1 sentry-sdk-0.19.5 shortuuid-1.0.1 smmap-3.0.4 subprocess32-3.5.4 wandb-0.8.36 watchdog-1.0.1

# %%
import wandb
wandb.login()
# Out:
# wandb: ERROR Not authenticated.  Copy a key from https://app.wandb.ai/authorize
# API Key: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# ### Restoring model weights from GCS Bucket

# %%
from google.colab import auth
auth.authenticate_user()

PROJECT_ID = "fast-ai-exploration" 
# !gcloud config set project $PROJECT_ID
# Out:
# Updated property [core/project].
# WARNING: You do not appear to have access to project [fast-ai-exploration] or it does not exist.

# %%
# !gsutil cp gs://resnet_simclr_imagenet/20200508-134915resnet_simclr.h5 .
# Out:
# AccessDeniedException: 403 atulshah16@gmail.com does not have storage.objects.list access to the Google Cloud Storage bucket.

# %% [markdown]
# ### Restoring model weights from `wandb` run page

# %%
simclr_weights = wandb.restore("20200509-042927resnet_simclr.h5", run_path="sayakpaul/simclr/simclr-learning")

# %%
# Other imports
from sklearn.preprocessing import LabelEncoder
from sklearn.manifold import TSNE
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from wandb.keras import WandbCallback
import matplotlib.pyplot as plt
from imutils import paths
from tqdm import tqdm
import tensorflow as tf
import seaborn as sns
import numpy as np
import cv2

# Random seed fixation
tf.random.set_seed(666)
np.random.seed(666)

# %% [markdown]
# ## Dataset gathering and preparation

# %%
# Gather dataset
# !git clone https://github.com/thunderInfy/imagenet-5-categories
# Out:
# Cloning into 'imagenet-5-categories'...
# remote: Enumerating objects: 1532, done.
# remote: Total 1532 (delta 0), reused 0 (delta 0), pack-reused 1532
# Receiving objects: 100% (1532/1532), 88.56 MiB | 50.55 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# Train and test image paths
train_images = list(paths.list_images("imagenet-5-categories/train"))
test_images = list(paths.list_images("imagenet-5-categories/test"))
print(len(train_images), len(test_images))
# Out:
# 1250 250

# %%
# 10% of the dataset
train_images_10 = np.random.choice(train_images, len(train_images)//10)
len(train_images_10)
# Out:
# 125

# %%
def prepare_images(image_paths):
    images = []
    labels = []

    for image in tqdm(image_paths):
        image_pixels = plt.imread(image)
        image_pixels = cv2.resize(image_pixels, (224, 224))
        image_pixels = image_pixels/255.

        label = image.split("/")[2].split("_")[0]

        images.append(image_pixels)
        labels.append(label)

    images = np.array(images)
    labels = np.array(labels)

    print(images.shape, labels.shape)

    return images, labels

# %%
X_train, y_train = prepare_images(train_images_10)
X_test, y_test = prepare_images(test_images)
# Out:
# 100%|██████████| 125/125 [00:00<00:00, 204.20it/s]
#  11%|█         | 27/250 [00:00<00:00, 264.23it/s]
# (125, 224, 224, 3) (125,)
# 100%|██████████| 250/250 [00:01<00:00, 223.51it/s]
# (250, 224, 224, 3) (250,)

# %%
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)

# %% [markdown]
# ## Utilities

# %%
# Architecture utils
def get_resnet_simclr(hidden_1, hidden_2, hidden_3):
    base_model = tf.keras.applications.ResNet50(include_top=False, weights=None, input_shape=(224, 224, 3))
    base_model.trainable = True
    inputs = Input((224, 224, 3))
    h = base_model(inputs, training=False)
    h = GlobalAveragePooling2D()(h)

    projection_1 = Dense(hidden_1)(h)
    projection_1 = Activation("relu")(projection_1)
    projection_2 = Dense(hidden_2)(projection_1)
    projection_2 = Activation("relu")(projection_2)
    projection_3 = Dense(hidden_3)(projection_2)

    resnet_simclr = Model(inputs, projection_3)

    return resnet_simclr

# %%
resnet_simclr = get_resnet_simclr(256, 128, 50)
resnet_simclr.load_weights(simclr_weights.name)
resnet_simclr.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                6450
# =================================================================
# Total params: 24,151,602
# Trainable params: 24,098,482
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
def plot_training(H):
	with plt.xkcd():
		plt.plot(H.history["loss"], label="train_loss")
		plt.plot(H.history["val_loss"], label="val_loss")
		plt.plot(H.history["accuracy"], label="train_acc")
		plt.plot(H.history["val_accuracy"], label="val_acc")
		plt.title("Training Loss and Accuracy")
		plt.xlabel("Epoch #")
		plt.ylabel("Loss/Accuracy")
		plt.legend(loc="lower left")
		plt.show()

# %%
def get_linear_model(features):
    linear_model = Sequential([Dense(5, input_shape=(features, ), activation="softmax")])
    return linear_model

# %% [markdown]
# ## Evaluation

# %%
resnet_simclr.layers[1].trainable = False
resnet_simclr.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                6450
# =================================================================
# Total params: 24,151,602
# Trainable params: 563,890
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
# Encoder model with non-linear projections
projection = Model(resnet_simclr.input, resnet_simclr.layers[-2].output)

# Extract train and test features
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)

print(train_features.shape, test_features.shape)
# Out:
# (125, 128) (250, 128)

# %%
# Early Stopping to prevent overfitting
es = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=2, verbose=2, restore_best_weights=True)

# %%
# Linear model
wandb.init(project="simclr", id="linear-eval-relu-last")

linear_model = get_linear_model(128)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es, WandbCallback()])
plot_training(history)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/atulshah16/simclr" target="_blank">https://app.wandb.ai/atulshah16/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/atulshah16/simclr/runs/linear-eval-relu-last" target="_blank">https://app.wandb.ai/atulshah16/simclr/runs/linear-eval-relu-last</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# Epoch 1/35
# 2/2 [==============================] - 0s 84ms/step - loss: 3.2349 - accuracy: 0.1680 - val_loss: 3.1227 - val_accuracy: 0.1800
# Epoch 2/35
# 2/2 [==============================] - 0s 27ms/step - loss: 3.0188 - accuracy: 0.2080 - val_loss: 2.9597 - val_accuracy: 0.1920
# Epoch 3/35
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8145 - accuracy: 0.2480 - val_loss: 2.8170 - val_accuracy: 0.2080
# Epoch 4/35
# 2/2 [==============================] - 0s 23ms/step - loss: 2.6309 - accuracy: 0.2640 - val_loss: 2.6946 - val_accuracy: 0.2120
# Epoch 5/35
# 2/2 [==============================] - 0s 22ms/step - loss: 2.4884 - accuracy: 0.2800 - val_loss: 2.5871 - val_accuracy: 0.2320
# Epoch 6/35
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3411 - accuracy: 0.2800 - val_loss: 2.4962 - val_accuracy: 0.2480
# Epoch 7/35
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2307 - accuracy: 0.2960 - val_loss: 2.4177 - val_accuracy: 0.2680
# Epoch 8/35
# 2/2 [==============================] - 0s 23ms/step - loss: 2.1215 - accuracy: 0.3040 - val_loss: 2.3490 - val_accuracy: 0.2640
# Epoch 9/35
# 2/2 [==============================] - 0s 23ms/step - loss: 2.0299 - accuracy: 0.3040 - val_loss: 2.2890 - val_accuracy: 0.2800
# Epoch 10/35
# 2/2 [==============================] - 0s 21ms/step - loss: 1.9540 - accuracy: 0.3440 - val_loss: 2.2360 - val_accuracy: 0.2800
# Epoch 11/35
# 2/2 [==============================] - 0s 21ms/step - loss: 1.8858 - accuracy: 0.3920 - val_loss: 2.1881 - val_accuracy: 0.3200
# Epoch 12/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.8191 - accuracy: 0.3920 - val_loss: 2.1431 - val_accuracy: 0.3280
# Epoch 13/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.7632 - accuracy: 0.4240 - val_loss: 2.1000 - val_accuracy: 0.3320
# Epoch 14/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.7071 - accuracy: 0.4320 - val_loss: 2.0596 - val_accuracy: 0.3320
# Epoch 15/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.6594 - accuracy: 0.4400 - val_loss: 2.0212 - val_accuracy: 0.3360
# Epoch 16/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.6133 - accuracy: 0.4560 - val_loss: 1.9829 - val_accuracy: 0.3400
# Epoch 17/35
# 2/2 [==============================] - 0s 27ms/step - loss: 1.5711 - accuracy: 0.4720 - val_loss: 1.9462 - val_accuracy: 0.3400
# Epoch 18/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.5289 - accuracy: 0.4800 - val_loss: 1.9128 - val_accuracy: 0.3520
# Epoch 19/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.4914 - accuracy: 0.4880 - val_loss: 1.8803 - val_accuracy: 0.3600
# Epoch 20/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.4565 - accuracy: 0.5040 - val_loss: 1.8510 - val_accuracy: 0.3600
# Epoch 21/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.4238 - accuracy: 0.5040 - val_loss: 1.8236 - val_accuracy: 0.3640
# Epoch 22/35
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3952 - accuracy: 0.4880 - val_loss: 1.7984 - val_accuracy: 0.3680
# Epoch 23/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.3642 - accuracy: 0.5040 - val_loss: 1.7770 - val_accuracy: 0.3800
# Epoch 24/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.3405 - accuracy: 0.5040 - val_loss: 1.7567 - val_accuracy: 0.3920
# Epoch 25/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.3174 - accuracy: 0.5120 - val_loss: 1.7385 - val_accuracy: 0.3960
# Epoch 26/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2956 - accuracy: 0.5200 - val_loss: 1.7221 - val_accuracy: 0.4000
# Epoch 27/35
# 2/2 [==============================] - 0s 28ms/step - loss: 1.2737 - accuracy: 0.5200 - val_loss: 1.7060 - val_accuracy: 0.4080
# Epoch 28/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.2549 - accuracy: 0.5280 - val_loss: 1.6911 - val_accuracy: 0.4200
# Epoch 29/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.2367 - accuracy: 0.5360 - val_loss: 1.6788 - val_accuracy: 0.4160
# Epoch 30/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.2172 - accuracy: 0.5360 - val_loss: 1.6670 - val_accuracy: 0.4160
# Epoch 31/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.2019 - accuracy: 0.5360 - val_loss: 1.6562 - val_accuracy: 0.4200
# Epoch 32/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.1857 - accuracy: 0.5440 - val_loss: 1.6463 - val_accuracy: 0.4160
# Epoch 33/35
# 2/2 [==============================] - 0s 21ms/step - loss: 1.1704 - accuracy: 0.5440 - val_loss: 1.6372 - val_accuracy: 0.4120
# Epoch 34/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1562 - accuracy: 0.5520 - val_loss: 1.6294 - val_accuracy: 0.4200
# Epoch 35/35
# 2/2 [==============================] - 0s 21ms/step - loss: 1.1416 - accuracy: 0.5680 - val_loss: 1.6220 - val_accuracy: 0.4200

# %%
# Encoder model with less non-linearity
projection = Model(resnet_simclr.input, resnet_simclr.layers[-4].output)

# Extract train and test features
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)

print(train_features.shape, test_features.shape)
# Out:
# (125, 256) (250, 256)

# %%
wandb.init(project="simclr", id="linear-eval-relu-second-last")

linear_model = get_linear_model(256)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es, WandbCallback()])
plot_training(history)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/atulshah16/simclr" target="_blank">https://app.wandb.ai/atulshah16/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/atulshah16/simclr/runs/linear-eval-relu-second-last" target="_blank">https://app.wandb.ai/atulshah16/simclr/runs/linear-eval-relu-second-last</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# Epoch 1/35
# 2/2 [==============================] - 0s 61ms/step - loss: 4.2159 - accuracy: 0.2640 - val_loss: 3.3822 - val_accuracy: 0.3000
# Epoch 2/35
# 2/2 [==============================] - 0s 22ms/step - loss: 3.6783 - accuracy: 0.3200 - val_loss: 2.9722 - val_accuracy: 0.3080
# Epoch 3/35
# 2/2 [==============================] - 0s 23ms/step - loss: 3.2617 - accuracy: 0.3360 - val_loss: 2.6655 - val_accuracy: 0.3080
# Epoch 4/35
# 2/2 [==============================] - 0s 25ms/step - loss: 2.9106 - accuracy: 0.3360 - val_loss: 2.4360 - val_accuracy: 0.3200
# Epoch 5/35
# 2/2 [==============================] - 0s 23ms/step - loss: 2.6433 - accuracy: 0.3680 - val_loss: 2.2529 - val_accuracy: 0.3240
# Epoch 6/35
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4082 - accuracy: 0.3520 - val_loss: 2.1180 - val_accuracy: 0.3200
# Epoch 7/35
# 2/2 [==============================] - 0s 25ms/step - loss: 2.2441 - accuracy: 0.3520 - val_loss: 2.0178 - val_accuracy: 0.3200
# Epoch 8/35
# 2/2 [==============================] - 0s 23ms/step - loss: 2.1180 - accuracy: 0.3200 - val_loss: 1.9489 - val_accuracy: 0.3120
# Epoch 9/35
# 2/2 [==============================] - 0s 29ms/step - loss: 2.0319 - accuracy: 0.3360 - val_loss: 1.8959 - val_accuracy: 0.3480
# Epoch 10/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.9781 - accuracy: 0.3520 - val_loss: 1.8479 - val_accuracy: 0.3480
# Epoch 11/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.9135 - accuracy: 0.3680 - val_loss: 1.7984 - val_accuracy: 0.3480
# Epoch 12/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.8423 - accuracy: 0.3760 - val_loss: 1.7344 - val_accuracy: 0.3760
# Epoch 13/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.7604 - accuracy: 0.4000 - val_loss: 1.6629 - val_accuracy: 0.3920
# Epoch 14/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.6815 - accuracy: 0.4320 - val_loss: 1.5870 - val_accuracy: 0.4240
# Epoch 15/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.6015 - accuracy: 0.4640 - val_loss: 1.5221 - val_accuracy: 0.4320
# Epoch 16/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.5336 - accuracy: 0.4800 - val_loss: 1.4702 - val_accuracy: 0.4480
# Epoch 17/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.4741 - accuracy: 0.4960 - val_loss: 1.4328 - val_accuracy: 0.4600
# Epoch 18/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.4259 - accuracy: 0.5120 - val_loss: 1.4098 - val_accuracy: 0.4840
# Epoch 19/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.3816 - accuracy: 0.5120 - val_loss: 1.3956 - val_accuracy: 0.5000
# Epoch 20/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.3479 - accuracy: 0.5120 - val_loss: 1.3879 - val_accuracy: 0.5000
# Epoch 21/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.3094 - accuracy: 0.5200 - val_loss: 1.3790 - val_accuracy: 0.5000
# Epoch 22/35
# 2/2 [==============================] - 0s 21ms/step - loss: 1.2759 - accuracy: 0.5280 - val_loss: 1.3683 - val_accuracy: 0.4960
# Epoch 23/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.2483 - accuracy: 0.5200 - val_loss: 1.3592 - val_accuracy: 0.4840
# Epoch 24/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.2168 - accuracy: 0.5280 - val_loss: 1.3540 - val_accuracy: 0.4720
# Epoch 25/35
# 2/2 [==============================] - 0s 21ms/step - loss: 1.1949 - accuracy: 0.5040 - val_loss: 1.3532 - val_accuracy: 0.4560
# Epoch 26/35
# 2/2 [==============================] - 0s 16ms/step - loss: 1.1807 - accuracy: 0.5200 - val_loss: 1.3549 - val_accuracy: 0.4520
# Epoch 27/35
# 2/2 [==============================] - 0s 21ms/step - loss: 1.1625 - accuracy: 0.5200 - val_loss: 1.3483 - val_accuracy: 0.4600
# Epoch 28/35
# 2/2 [==============================] - 0s 21ms/step - loss: 1.1462 - accuracy: 0.5120 - val_loss: 1.3398 - val_accuracy: 0.4800
# Epoch 29/35
# 2/2 [==============================] - 0s 26ms/step - loss: 1.1305 - accuracy: 0.5200 - val_loss: 1.3343 - val_accuracy: 0.4880
# Epoch 30/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.1164 - accuracy: 0.5520 - val_loss: 1.3278 - val_accuracy: 0.4960
# Epoch 31/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.1052 - accuracy: 0.5440 - val_loss: 1.3213 - val_accuracy: 0.5160
# Epoch 32/35
# 2/2 [==============================] - 0s 21ms/step - loss: 1.0920 - accuracy: 0.5600 - val_loss: 1.3168 - val_accuracy: 0.5160
# Epoch 33/35
# 2/2 [==============================] - 0s 23ms/step - loss: 1.0839 - accuracy: 0.5840 - val_loss: 1.3121 - val_accuracy: 0.5200
# Epoch 34/35
# 2/2 [==============================] - 0s 24ms/step - loss: 1.0745 - accuracy: 0.6000 - val_loss: 1.3101 - val_accuracy: 0.5240
# Epoch 35/35
# 2/2 [==============================] - 0s 22ms/step - loss: 1.0647 - accuracy: 0.5840 - val_loss: 1.3080 - val_accuracy: 0.5280

# %%
# Encoder model with no projection
projection = Model(resnet_simclr.input, resnet_simclr.layers[-6].output)

# Extract train and test features
train_features = projection.predict(X_train)
test_features = projection.predict(X_test)

print(train_features.shape, test_features.shape)
# Out:
# (125, 2048) (250, 2048)

# %%
wandb.init(project="simclr", id="linear-eval-no-projections")

linear_model = get_linear_model(2048)
linear_model.compile(loss="sparse_categorical_crossentropy", metrics=["accuracy"],
                     optimizer="adam")
history = linear_model.fit(train_features, y_train_enc,
                 validation_data=(test_features, y_test_enc),
                 batch_size=64,
                 epochs=35,
                 callbacks=[es, WandbCallback()])
plot_training(history)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/atulshah16/simclr" target="_blank">https://app.wandb.ai/atulshah16/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/atulshah16/simclr/runs/linear-eval-no-projections" target="_blank">https://app.wandb.ai/atulshah16/simclr/runs/linear-eval-no-projections</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# Epoch 1/35
# 2/2 [==============================] - 0s 69ms/step - loss: 2.4883 - accuracy: 0.2000 - val_loss: 2.4593 - val_accuracy: 0.0760
# Epoch 2/35
# 2/2 [==============================] - 0s 24ms/step - loss: 2.0594 - accuracy: 0.1520 - val_loss: 2.2108 - val_accuracy: 0.2560
# Epoch 3/35
# 2/2 [==============================] - 0s 26ms/step - loss: 1.7150 - accuracy: 0.3520 - val_loss: 2.0180 - val_accuracy: 0.2920
# Epoch 4/35
# 2/2 [==============================] - 0s 27ms/step - loss: 1.5014 - accuracy: 0.4240 - val_loss: 1.5952 - val_accuracy: 0.3240
# Epoch 5/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.3284 - accuracy: 0.4640 - val_loss: 1.3364 - val_accuracy: 0.4800
# Epoch 6/35
# 2/2 [==============================] - 0s 25ms/step - loss: 1.1935 - accuracy: 0.4880 - val_loss: 1.3318 - val_accuracy: 0.4520
# Epoch 7/35
# 2/2 [==============================] - 0s 17ms/step - loss: 1.1774 - accuracy: 0.5760 - val_loss: 1.4062 - val_accuracy: 0.4360
# Epoch 8/35
# 1/2 [==============>...............] - ETA: 0s - loss: 1.1722 - accuracy: 0.5469Restoring model weights from the end of the best epoch.
# 2/2 [==============================] - 0s 17ms/step - loss: 1.1158 - accuracy: 0.5520 - val_loss: 1.3789 - val_accuracy: 0.4560
# Epoch 00008: early stopping

# %% [markdown]
# ## Visualization of the representations

# %%
wandb.init(project="simclr", id="visualization")
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/atulshah16/simclr" target="_blank">https://app.wandb.ai/atulshah16/simclr</a><br/>
#                 Run page: <a href="https://app.wandb.ai/atulshah16/simclr/runs/visualization" target="_blank">https://app.wandb.ai/atulshah16/simclr/runs/visualization</a><br/>
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# W&B Run: https://app.wandb.ai/atulshah16/simclr/runs/visualization

# %%
# Visualization of the representations
def plot_vecs_n_labels(v, labels):
    fig = plt.figure(figsize = (10, 10))
    sns.set_style("darkgrid")
    sns.scatterplot(v[:,0], v[:,1], hue=labels, legend='full', palette=sns.color_palette("bright", 5))
    plt.show()

    return fig

# %%
# Representations with no nonlinear projections
tsne = TSNE()
low_vectors = tsne.fit_transform(train_features)
fig = plot_vecs_n_labels(low_vectors, y_train_enc)
wandb.log({"no_no_linear_projection": fig})
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/mpltools.py:368: MatplotlibDeprecationWarning:
#
#
# The is_frame_like function was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/renderer.py:474: UserWarning:
#
# Dang! That path collection is out of this world. I totally don't know what to do with it yet! Plotly can only import path collections linked to 'data' coordinates
#
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/renderer.py:512: UserWarning:
#
# I found a path object that I don't think is part of a bar chart. Ignoring.

# %%
# Representations with second last ReLU
tsne = TSNE()
projection = Model(resnet_simclr.input, resnet_simclr.layers[-4].output)
train_features = projection.predict(X_train)
low_vectors = tsne.fit_transform(train_features)
fig = plot_vecs_n_labels(low_vectors, y_train_enc)
wandb.log({"second_last_relu": fig})
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/mpltools.py:368: MatplotlibDeprecationWarning:
#
#
# The is_frame_like function was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/renderer.py:474: UserWarning:
#
# Dang! That path collection is out of this world. I totally don't know what to do with it yet! Plotly can only import path collections linked to 'data' coordinates
#
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/renderer.py:512: UserWarning:
#
# I found a path object that I don't think is part of a bar chart. Ignoring.

# %%
# Representations with the last ReLU
tsne = TSNE()
projection = Model(resnet_simclr.input, resnet_simclr.layers[-2].output)
train_features = projection.predict(X_train)
low_vectors = tsne.fit_transform(train_features)
fig = plot_vecs_n_labels(low_vectors, y_train_enc)
wandb.log({"last_relu": fig})
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# wandb: Wandb version 0.10.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/mpltools.py:368: MatplotlibDeprecationWarning:
#
#
# The is_frame_like function was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/renderer.py:474: UserWarning:
#
# Dang! That path collection is out of this world. I totally don't know what to do with it yet! Plotly can only import path collections linked to 'data' coordinates
#
# /usr/local/lib/python3.6/dist-packages/plotly/matplotlylib/renderer.py:512: UserWarning:
#
# I found a path object that I don't think is part of a bar chart. Ignoring.
